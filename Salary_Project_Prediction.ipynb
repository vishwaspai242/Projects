# %% [markdown]
# # Salary Project

# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("salary_project.csv")
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (397, 6)

# %%
df.dtypes
# Out:
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %% [markdown]
# # Encoding:

# %% [raw]
# Since rank , discipline and sex also might play a role in salary prediction we used an label encoding technique to convert it into numerical data.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
list1=['rank','discipline','sex']

for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))
    
df
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0       2           1             19           18    1  139750
# 1       2           1             20           16    1  173200
# 2       1           1              4            3    1   79750
# 3       2           1             45           39    1  115000
# 4       2           1             40           41    1  141500
# ..    ...         ...            ...          ...  ...     ...
# 392     2           0             33           30    1  103106
# 393     2           0             31           19    1  150564
# 394     2           0             42           25    1  101738
# 395     2           0             25           15    1   95329
# 396     1           0              8            4    1   81035
#
# [397 rows x 6 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# # Scatterplot:

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x='rank',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(x='discipline',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='salary'>

# %%
sns.scatterplot(x='yrs.since.phd',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(x='yrs.service',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
sns.scatterplot(x='sex',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='salary'>

# %% [raw]
# Outcome of scatter plot:
# -yrs.since.phd, yrs.service show positive relation when plotted against salary
# -rank, discipline and sex are categorical data

# %% [markdown]
# # Describing Datasets:

# %%
df.describe()
# Out:
#              rank  discipline  yrs.since.phd  yrs.service         sex  \
# count  397.000000  397.000000     397.000000   397.000000  397.000000
# mean     1.508816    0.544081      22.314861    17.614610    0.901763
# std      0.757486    0.498682      12.887003    13.006024    0.298010
# min      0.000000    0.000000       1.000000     0.000000    0.000000
# 25%      1.000000    0.000000      12.000000     7.000000    1.000000
# 50%      2.000000    1.000000      21.000000    16.000000    1.000000
# 75%      2.000000    1.000000      32.000000    27.000000    1.000000
# max      2.000000    1.000000      56.000000    60.000000    1.000000
#
#               salary
# count     397.000000
# mean   113706.458438
# std     30289.038695
# min     57800.000000
# 25%     91000.000000
# 50%    107300.000000
# 75%    134185.000000
# max    231545.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    int32
#  1   discipline     397 non-null    int32
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    int32
#  5   salary         397 non-null    int64
# dtypes: int32(3), int64(3)
# memory usage: 14.1 KB

# %% [raw]
# Outcome of describe of datasets:
# From the above plotting we are determining mean, standard deviation, min and max values of each column.

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#                    rank  discipline  yrs.since.phd  yrs.service       sex  \
# rank           1.000000   -0.086266       0.525500     0.447499  0.132492
# discipline    -0.086266    1.000000      -0.218087    -0.164599  0.003724
# yrs.since.phd  0.525500   -0.218087       1.000000     0.909649  0.148788
# yrs.service    0.447499   -0.164599       0.909649     1.000000  0.153740
# sex            0.132492    0.003724       0.148788     0.153740  1.000000
# salary         0.522207    0.156084       0.419231     0.334745  0.138610
#
#                  salary
# rank           0.522207
# discipline     0.156084
# yrs.since.phd  0.419231
# yrs.service    0.334745
# sex            0.138610
# salary         1.000000

# %%
corr_hmap=df.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [raw]
# Outcome of Correlation:
# -rank, yrs.since.phd, yrs.service have high positive correlation with salary
# -discipline and sex have less correlation with salary.

# %% [markdown]
# # Outliers Checking:

# %%
df.plot(kind='box',subplots=True,layout=(2,3),figsize=(10,12))
# Out:
# rank                AxesSubplot(0.125,0.536818;0.227941x0.343182)
# discipline       AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# yrs.since.phd    AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# yrs.service            AxesSubplot(0.125,0.125;0.227941x0.343182)
# sex                 AxesSubplot(0.398529,0.125;0.227941x0.343182)
# salary              AxesSubplot(0.672059,0.125;0.227941x0.343182)
# dtype: object

# %% [raw]
# Outcome of Outliers Checking:
# -Salary has moderate outliers.
# -All the other columns dont have outliers.

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df["rank"])
# Out:
# <AxesSubplot:xlabel='rank', ylabel='Density'>

# %%
sns.distplot(df["discipline"])
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='Density'>

# %%
sns.distplot(df["yrs.since.phd"])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='Density'>

# %%
sns.distplot(df["yrs.service"])
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='Density'>

# %%
sns.distplot(df["sex"])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Density'>

# %%
sns.distplot(df["salary"])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %% [markdown]
# # Skewness:

# %%
df.skew()
# Out:
# rank            -1.151164
# discipline      -0.177684
# yrs.since.phd    0.300880
# yrs.service      0.650569
# sex             -2.709958
# salary           0.714568
# dtype: float64

# %% [raw]
# Outcome of the skewness:  No changes to be made
# -Outcome of the skewness: Skewness threshold is taken as +/-0.65
#     Rank and sex are categorical encoded values hence skewness is irrelevant
#     yrs.service is just within the range of skewness threshold
#     salary is the target hence skewness is ok to proceed with

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Data Cleaning:

# %%
df.corr()['salary']
# Out:
# rank             0.522207
# discipline       0.156084
# yrs.since.phd    0.419231
# yrs.service      0.334745
# sex              0.138610
# salary           1.000000
# Name: salary, dtype: float64

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (397, 6)

# %%
threshold=3     #index number
print(np.where(z>3))
# Out:
# (array([  9,  19,  24,  34,  35,  43,  47,  48,  52,  63,  68,  84,  90,
#        103, 114, 119, 123, 127, 131, 132, 133, 148, 153, 179, 186, 218,
#        230, 231, 233, 237, 245, 253, 254, 274, 316, 323, 330, 332, 334,
#        341, 358, 361, 364], dtype=int64), array([4, 4, 4, 4, 4, 5, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 4, 4, 4, 4, 4, 5],
#       dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 43

# %%
z.iloc[131]   #single number 3 column
# Out:
# rank             0.649257
# discipline       1.092415
# yrs.since.phd    2.617183
# yrs.service      3.032063
# sex              0.330058
# salary           1.218691
# Name: 131, dtype: float64

# %% [raw]
# Outcome:
# since columns 4 - Sex (categorical encoded values) and 5 - Salary the zscore for them can be ignored.
# in column yrs.service 1 value has z score just slightly above 3 hence we can more forward without any removal of data since its a real value.

# %% [markdown]
# # Dividing the data into input variables and target:

# %%
x=df.iloc[:,:-1]          #input variables
y=df.iloc[:,-1]           #target

# %%
x
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  sex
# 0       2           1             19           18    1
# 1       2           1             20           16    1
# 2       1           1              4            3    1
# 3       2           1             45           39    1
# 4       2           1             40           41    1
# ..    ...         ...            ...          ...  ...
# 392     2           0             33           30    1
# 393     2           0             31           19    1
# 394     2           0             42           25    1
# 395     2           0             25           15    1
# 396     1           0              8            4    1
#
# [397 rows x 5 columns]

# %%
y
# Out:
# 0      139750
# 1      173200
# 2       79750
# 3      115000
# 4      141500
#         ...
# 392    103106
# 393    150564
# 394    101738
# 395     95329
# 396     81035
# Name: salary, Length: 397, dtype: int64

# %% [markdown]
# # Since the y (Target) has continuous values we will use Linear Regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
lr = LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is : {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is : {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is : 0.3611999954853078
# At random state 0,the testing accuracy is : 0.4079258314975238
#
#
# At random state 1,the training accuracy is : 0.3604245854198438
# At random state 1,the testing accuracy is : 0.41633641876629457
#
#
# At random state 2,the training accuracy is : 0.37547390964955596
# At random state 2,the testing accuracy is : 0.3600189554526695
#
#
# At random state 3,the training accuracy is : 0.3847313825130595
# At random state 3,the testing accuracy is : 0.3293529875010861
#
#
# At random state 4,the training accuracy is : 0.38517450334380454
# At random state 4,the testing accuracy is : 0.304400813331562
#
#
# At random state 5,the training accuracy is : 0.3950033630150771
# At random state 5,the testing accuracy is : 0.2752907752774737
#
#
# At random state 6,the training accuracy is : 0.3650308031752798
# At random state 6,the testing accuracy is : 0.4018987080607568
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=79)

# %%
x_train.shape
# Out:
# (317, 5)

# %%
y_train.shape
# Out:
# (317,)

# %%
x_test.shape
# Out:
# (80, 5)

# %%
y_test.shape
# Out:
# (80,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.34007344678049267

# %%
lr.coef_
# Out:
# array([15884.31453989, 16075.21676804,   968.14657835,  -444.7409568 ,
#         3348.98261513])

# %%
pred_test=lr.predict(x_test)
pred_test
# Out:
# array([ 87992.2854175 , 107201.61004778,  85611.251304  , 124970.15414863,
#        130707.34078362,  93287.16156325, 116595.66420393, 136488.97322205,
#         82785.67431042, 107540.43930819, 135523.90307391,  95719.81138656,
#        101320.39177998, 142797.08771223, 120102.17422525, 122589.12003514,
#         88673.02036853, 121542.30879205, 122804.83882737, 117563.81078227,
#        127871.51745347, 100718.51957041, 123328.24444891,  88053.10534781,
#        121802.47338772,  73914.18173647, 124453.72035674, 124628.24845802,
#        117642.47544701, 123406.90911365, 119681.80194661,  76503.96281254,
#        119814.76259793,  85087.84568246, 130368.51152321,  89117.76132533,
#         87608.56246772, 107697.76863768, 123974.76053864, 100796.98615844,
#        126547.34284292, 134658.59176175,  88942.58726142, 122804.83882737,
#         92022.20106037,  79069.57328717, 136047.30869545, 101686.46807204,
# ...

# %%
mean_squared_error(y_test,pred_test)
# Out:
# 415721178.7024126

# %%
np.sqrt(mean_squared_error(y_test,pred_test))
# Out:
# 20389.241739270557

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.508490881969465

# %% [markdown]
# # Cross Validation of the model:

# %%
pred_test=lr.predict(x_test)

# %%
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.3270801167406509 and accuracy score for training is -0.35258364717468793 and for testing is 0.508490881969465
#
#
# At cross fold 3 the cv score is 0.3203328673059878 and accuracy score for training is -0.35258364717468793 and for testing is 0.508490881969465
#
#
# At cross fold 4 the cv score is 0.3218196693768358 and accuracy score for training is -0.35258364717468793 and for testing is 0.508490881969465
#
#
# At cross fold 5 the cv score is 0.29569928663871775 and accuracy score for training is -0.35258364717468793 and for testing is 0.508490881969465
#
#
# At cross fold 6 the cv score is 0.3309634183929555 and accuracy score for training is -0.35258364717468793 and for testing is 0.508490881969465
#
#
# At cross fold 7 the cv score is 0.3257704419996536 and accuracy score for training is -0.35258364717468793 and for testing is 0.508490881969465
#
#
# ...

# %% [markdown]
# We will plot a scatter plot for Linear Regression

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test, color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=14)
plt.show()

# %% [markdown]
# some data points are not being fit in the best fit line. Hence we will use a different approach.

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}

ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
predlasso=ls.predict(x_test)

lss=r2_score(y_test,predlasso)
lss
# Out:
# 0.5083201017840312

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.29575407060855924

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
print(rd.score(x_train,y_train))
predridge=rd.predict(x_test)
print(mean_squared_error(y_test,predridge))
print('Mean squared error:',np.sqrt(mean_squared_error(y_test,predridge)))
print(r2_score(y_test,predridge))
# Out:
# 0.3400734467803087
# 415721163.7253679
# Mean squared error: 20389.241371992433
# 0.5084908996768959

# %%
enr = ElasticNet(alpha=0.0001)
enr.fit(x_train,y_train)
print(enr.score(x_train,y_train))
enrpred=enr.predict(x_test)
print(mean_squared_error(y_test,enrpred))
print('Mean squared error:',np.sqrt(mean_squared_error(y_test,enrpred)))
print(r2_score(y_test,enrpred))
# Out:
# 0.3400734421599191
# 415718809.6543156
# Mean squared error: 20389.183643645854
# 0.5084936829062476

# %% [markdown]
# # Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf = RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision = rf.predict(x_test)

rfs = r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,x,y,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 43.05351844018925
# Cross Val Score: 23.92366563767298

# %% [raw]
# Out of All the above the Linear Regression has the highest Score hence we used Linear Regression model for saving and predicting the data

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename = 'Salary_Project_Prediction.pkl'
pickle.dump(enr, open(filename, 'wb'))

# %% [markdown]
# # Prediction Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(enr.predict(x_test))
df_comparison = pd.DataFrame({"original":a,"predicted":predicted},index= range(len(a)))
df_comparison
# Out:
#     original      predicted
# 0      74000   87994.458420
# 1      84273  107202.548363
# 2      72500   85613.420598
# 3      89650  124971.670960
# 4     124714  130704.824753
# ..       ...            ...
# 75    112429  111283.785699
# 76    175000  133924.109146
# 77     88825  104145.007829
# 78     63100   83914.866731
# 79     84500  105191.867916
#
# [80 rows x 2 columns]
